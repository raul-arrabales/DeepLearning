# %% [markdown]
# # Spark Hands On Training
# ## Databricks CE Cloud Practice
# ### Raul Arrabales / Conscious-Robots.com

# %% [markdown]
# ### Hello Word Exercise using RDDs
# Distributed wordcount with El Quijote as dataset

# %% [markdown]
# - First step is to load de dataset<br>
# Download the text file from: https://www.gutenberg.org/ebooks/2000.txt.utf-8
# <br>and load it into the Spark Cluster DBFS (or maybe load into memory directly from the network)

# %%
import os, sys
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansigreen">&lt;command-85357491196634&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>sys<span class="ansiyellow">.</span>setdefaultencoding<span class="ansiyellow">(</span><span class="ansiblue">&apos;utf-8&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">AttributeError</span>: module &apos;sys&apos; has no attribute &apos;setdefaultencoding&apos;</div>

# %%
# Load text lines into an RDD
rdd1 = sc.textFile('/FileStore/tables/2ndixk251466511975346/quijote.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd1.takeSample(False, 10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>
# [&apos;&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;libertad hasta que fuesen todos juntos, porque la experiencia le hab�a&apos;,
#  &apos;Tomado, pues, este apuntamiento, y habiendo imaginado el duque lo que hab�a&apos;,
#  &apos;vanos de caballer�as est�n esparcidas.&apos;,
#  &apos;sin gobierno salistes del vientre de vuestra madre, sin gobierno hab�is&apos;]
# </div>

# %%
rdd1.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>
# [&apos;Project Gutenberg Etext of Don Quijote, by Cervantes, in Spanish&apos;,
#  &apos;&apos;,
#  &apos;#2 in our series by Cervantes&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;We will be presenting two versions of this, one in HTML and one&apos;,
#  &apos;&apos;,
#  &apos;in &quot;Plain Upper ASCII Spanish.&quot;&apos;,
#  &apos;&apos;]
# </div>

# %%
rdd1.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">39</span><span class="ansired">]: </span>74294
# </div>

# %%
# Nested wordcount:
wordcounts = rdd1.map( lambda x: x.replace(',',' ').replace('.',' ').replace('-',' ').lower()) \
        .flatMap(lambda x: x.split()) \
        .map(lambda x: (x, 1)) \
        .reduceByKey(lambda x,y:x+y) \
        .map(lambda x:(x[1],x[0])) \
        .sortByKey(False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd2 = rdd1.map( lambda x: x.replace('.',' ').replace('-',' ').lower())
rdd2.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>
# [&apos;project gutenberg etext of don quijote, by cervantes, in spanish&apos;,
#  &apos;&apos;,
#  &apos;#2 in our series by cervantes&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;&apos;,
#  &apos;we will be presenting two versions of this, one in html and one&apos;,
#  &apos;&apos;,
#  &apos;in &quot;plain upper ascii spanish &quot;&apos;,
#  &apos;&apos;]
# </div>

# %%
rdd3 = rdd2.flatMap(lambda x: x.split())
rdd3.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>384729
# </div>

# %%
rdd3.take(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>
# [&apos;project&apos;,
#  &apos;gutenberg&apos;,
#  &apos;etext&apos;,
#  &apos;of&apos;,
#  &apos;don&apos;,
#  &apos;quijote,&apos;,
#  &apos;by&apos;,
#  &apos;cervantes,&apos;,
#  &apos;in&apos;,
#  &apos;spanish&apos;,
#  &apos;#2&apos;,
#  &apos;in&apos;,
#  &apos;our&apos;,
#  &apos;series&apos;,
#  &apos;by&apos;,
#  &apos;cervantes&apos;,
#  &apos;we&apos;,
#  &apos;will&apos;,
#  &apos;be&apos;,
#  &apos;presenting&apos;]
# </div>

# %%
rdd4 = rdd3.map(lambda x: (x, 1))
rdd4.take(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>
# [(&apos;project&apos;, 1),
#  (&apos;gutenberg&apos;, 1),
#  (&apos;etext&apos;, 1),
#  (&apos;of&apos;, 1),
#  (&apos;don&apos;, 1),
#  (&apos;quijote,&apos;, 1),
#  (&apos;by&apos;, 1),
#  (&apos;cervantes,&apos;, 1),
#  (&apos;in&apos;, 1),
#  (&apos;spanish&apos;, 1),
#  (&apos;#2&apos;, 1),
#  (&apos;in&apos;, 1),
#  (&apos;our&apos;, 1),
#  (&apos;series&apos;, 1),
#  (&apos;by&apos;, 1)]
# </div>

# %%
rdd5 = rdd4.reduceByKey(lambda x,y:x+y)
rdd5.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>34465
# </div>

# %%
rdd5.takeSample(False, 15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>
# [(&apos;r�tulo,&apos;, 1),
#  (&apos;corrob�ranse&apos;, 1),
#  (&apos;consol�se&apos;, 2),
#  (&apos;pistoletes&apos;, 1),
#  (&apos;examen,&apos;, 1),
#  (&apos;desviarse,&apos;, 1),
#  (&apos;preciaba&apos;, 1),
#  (&apos;defensor&apos;, 2),
#  (&apos;declinaci�n&apos;, 1),
#  (&apos;confiado&apos;, 3),
#  (&apos;escuchar�an&apos;, 1),
#  (&apos;�monta&apos;, 1),
#  (&apos;mentiras&apos;, 6),
#  (&apos;candiles!&apos;, 1),
#  (&apos;gallardo&apos;, 14)]
# </div>

# %%
rdd6 = rdd5.map(lambda x:(x[1],x[0]))
rdd6.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>
# [(1, &apos;aguard�ndome,&apos;),
#  (1, &apos;ensanche;&apos;),
#  (1, &apos;atribuirlo,&apos;),
#  (1, &apos;sepultarlas&apos;),
#  (1, &apos;susto,&apos;),
#  (27, &apos;aventura,&apos;),
#  (4, &apos;pares,&apos;),
#  (160, &apos;vez&apos;),
#  (1, &apos;buscarnos,&apos;),
#  (1, &apos;caballeros:&apos;)]
# </div>

# %%
rdd7 = rdd6.sortByKey(False)
rdd7.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>
# [(19513, &apos;que&apos;),
#  (18191, &apos;de&apos;),
#  (16573, &apos;y&apos;),
#  (10358, &apos;la&apos;),
#  (9826, &apos;a&apos;),
#  (8201, &apos;en&apos;),
#  (8199, &apos;el&apos;),
#  (6037, &apos;no&apos;),
#  (4744, &apos;los&apos;),
#  (4690, &apos;se&apos;)]
# </div>

# %%
display(rdd7.take(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th></tr></thead><tbody><tr><td>19513</td><td>que</td></tr><tr><td>18191</td><td>de</td></tr><tr><td>16573</td><td>y</td></tr><tr><td>10358</td><td>la</td></tr><tr><td>9826</td><td>a</td></tr></tbody></table></div>
